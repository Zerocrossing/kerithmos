# %% [markdown]
# # $Kerithmos$
# Identifying numbers using keras
# ***

# %% [markdown]
# ## Setup
# Here we do all our imports, as well as define any constants we use throughout the notebook.

# %%
# from tensorflow.keras import 
import numpy as np
from matplotlib import pyplot as plt
from scipy.io import loadmat
import tensorflow.keras as kr

# %%
# consts
DATA_DIR = "../data/"
IMG_DIMS = (32,32,3)
NUM_CLASSES = 10

# %% [markdown]
# ## Load Data
# Now we load the sample data from files and rearrange into appropriate format. Keras expects images in the form (samples,channels,x,y) or (samples,x,y,channels). Given the data is stored (x,y,channels,samples) we will use np.moveaxis to change it to a more conventional (and plotable) format.

# %%
kr.backend.set_image_data_format('channels_last') #this should be default, but just in case
train_data = loadmat(DATA_DIR + "train.mat")
test_data = loadmat(DATA_DIR + "test.mat")
X = train_data["X"]
X = np.moveaxis(X, -1, 0)
y = train_data["y"].flatten()-1 # matlab starts arrays at 1
X_test = test_data["X"]
X_test = np.moveaxis(X_test.T, -1, 0)
y_test = test_data["y"].flatten()-1 # matlab starts arrays at 1
X.shape #sanity check
# Out:
# (73257, 32, 32, 3)

# %% [markdown]
# Plot a random selection and it's corresponding label:

# %%
plt.figure(figsize=(10,10))
for i in range(16):
    rnd = np.random.randint(0,X.shape[0])
    plt.subplot(4, 4, i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(X[rnd])
    plt.xlabel(y[rnd]%10) #data treats 10 as 0
plt.show()

# %% [markdown]
# ## Preprocess Data

# %%
X = X / 255.0
X_test = X_test / 255.0

# %% [markdown]
# ## Prepare Model

# %%
# consts / params
optimizer = 'adam'
loss='sparse_categorical_crossentropy'
metrics=['accuracy']

# %%
# a standard MLP
NUM_UNITS = 128
NUM_LAYERS = 4
dense_model = kr.models.Sequential()
dense_model.add(kr.layers.Flatten(input_shape=IMG_DIMS))
# dense_model.add(kr.layers.Dense(NUM_UNITS, input_shape=(32,32,3)))
for n in range(NUM_LAYERS):
    dense_model.add(kr.layers.Dense(NUM_UNITS, activation='relu'))
dense_model.add(kr.layers.Dense(NUM_CLASSES, activation='softmax'))
dense_model.compile(optimizer=optimizer, loss=loss, metrics=metrics)
dense_model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_16 (Flatten)         (None, 3072)              0
# _________________________________________________________________
# dense_113 (Dense)            (None, 128)               393344
# _________________________________________________________________
# dense_114 (Dense)            (None, 128)               16512
# _________________________________________________________________
# dense_115 (Dense)            (None, 128)               16512
# _________________________________________________________________
# dense_116 (Dense)            (None, 128)               16512
# _________________________________________________________________
# dense_117 (Dense)            (None, 10)                1290
# =================================================================
# Total params: 444,170
# Trainable params: 444,170
# Non-trainable params: 0
# _________________________________________________________________

# %%
# a standard CNN
NUM_FILTERS = 256
NUM_LAYERS = 4
cnn = kr.models.Sequential()
# cnn.add(kr.layers.Dense(NUM_UNITS, input_shape=IMG_DIMS, activation='relu'))
cnn.add(kr.layers.Conv2D(NUM_FILTERS,3, activation='relu', padding='same', input_shape=IMG_DIMS ))
for n in range(NUM_LAYERS):
    cnn.add(kr.layers.Conv2D(NUM_FILTERS, kernel_size=3, activation='relu', padding='same'))
    cnn.add(kr.layers.MaxPooling2D(pool_size=(2,2)))
    cnn.add(kr.layers.BatchNormalization())
cnn.add(kr.layers.Flatten())
cnn.add(kr.layers.Dense(NUM_CLASSES, activation='softmax'))
cnn.compile(optimizer=optimizer, loss=loss, metrics=metrics)
cnn.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_58 (Conv2D)           (None, 30, 30, 256)       7168
# _________________________________________________________________
# conv2d_59 (Conv2D)           (None, 30, 30, 256)       590080
# _________________________________________________________________
# max_pooling2d_37 (MaxPooling (None, 15, 15, 256)       0
# _________________________________________________________________
# batch_normalization_41 (Batc (None, 15, 15, 256)       1024
# _________________________________________________________________
# conv2d_60 (Conv2D)           (None, 15, 15, 256)       590080
# _________________________________________________________________
# max_pooling2d_38 (MaxPooling (None, 7, 7, 256)         0
# _________________________________________________________________
# batch_normalization_42 (Batc (None, 7, 7, 256)         1024
# _________________________________________________________________
# conv2d_61 (Conv2D)           (None, 7, 7, 256)         590080
# _________________________________________________________________
# max_pooling2d_39 (MaxPooling (None, 3, 3, 256)         0
# _________________________________________________________________
# batch_normalization_43 (Batc (None, 3, 3, 256)         1024
# _________________________________________________________________
# conv2d_62 (Conv2D)           (None, 3, 3, 256)         590080
# _________________________________________________________________
# max_pooling2d_40 (MaxPooling (None, 1, 1, 256)         0
# _________________________________________________________________
# batch_normalization_44 (Batc (None, 1, 1, 256)         1024
# _________________________________________________________________
# flatten_28 (Flatten)         (None, 256)               0
# _________________________________________________________________
# dense_141 (Dense)            (None, 10)                2570
# =================================================================
# Total params: 2,374,154
# Trainable params: 2,372,106
# Non-trainable params: 2,048
# _________________________________________________________________

# %% [markdown]
# ## Train Model

# %%
model = cnn # in case we add more later we can change the evaluation here
EPOCHS = 10

# %%
history = model.fit(X,y,epochs=EPOCHS, validation_split=0.2)
# Out:
# Train on 58605 samples, validate on 14652 samples
# Epoch 1/10
# 58605/58605 [==============================] - 108s 2ms/step - loss: 0.6074 - acc: 0.8096 - val_loss: 0.3588 - val_acc: 0.8928
# Epoch 2/10
# 58605/58605 [==============================] - 103s 2ms/step - loss: 0.2954 - acc: 0.9115 - val_loss: 0.2828 - val_acc: 0.9179
# Epoch 3/10
# 58605/58605 [==============================] - 103s 2ms/step - loss: 0.2230 - acc: 0.9339 - val_loss: 0.2629 - val_acc: 0.9214
# Epoch 4/10
# 58605/58605 [==============================] - 104s 2ms/step - loss: 0.1699 - acc: 0.9495 - val_loss: 0.2770 - val_acc: 0.9187
# Epoch 5/10
# 58605/58605 [==============================] - 104s 2ms/step - loss: 0.1283 - acc: 0.9616 - val_loss: 0.3069 - val_acc: 0.9178
# Epoch 6/10
#  2784/58605 [>.............................] - ETA: 1:31 - loss: 0.0817 - acc: 0.9752
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-224-6c8cb8fd562f> in <module>
# ----> 1 history = model.fit(X,y,epochs=EPOCHS, validation_split=0.2)
#
# C:\ProgramData\Anaconda3\envs\GPU ML\lib\site-packages\tensorflow\python\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, max_queue_size, workers, use_multiprocessing, **kwargs)
#    1637           initial_epoch=initial_epoch,
#    1638           steps_per_epoch=steps_per_epoch,
# -> 1639           validation_steps=validation_steps)
#    1640
#    1641   def evaluate(self,
#
# C:\ProgramData\Anaconda3\envs\GPU ML\lib\site-packages\tensorflow\python\keras\engine\training_arrays.py in fit_loop(model, inputs, targets, sample_weights, batch_size, epochs, verbose, callbacks, val_inputs, val_targets, val_sample_weights, shuffle, initial_epoch, steps_per_epoch, validation_steps)
#     213           ins_batch[i] = ins_batch[i].toarray()
#     214
# --> 215         outs = f(ins_batch)
#     216         if not isinstance(outs, list):
#     217           outs = [outs]
#
# C:\ProgramData\Anaconda3\envs\GPU ML\lib\site-packages\tensorflow\python\keras\backend.py in __call__(self, inputs)
#    2984
#    2985     fetched = self._callable_fn(*array_vals,
# -> 2986                                 run_metadata=self.run_metadata)
#    2987     self._call_fetch_callbacks(fetched[-len(self._fetches):])
#    2988     return fetched[:len(self.outputs)]
#
# C:\ProgramData\Anaconda3\envs\GPU ML\lib\site-packages\tensorflow\python\client\session.py in __call__(self, *args, **kwargs)
#    1437           ret = tf_session.TF_SessionRunCallable(
#    1438               self._session._session, self._handle, args, status,
# -> 1439               run_metadata_ptr)
#    1440         if run_metadata:
#    1441           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:

# %% [markdown]
# ## Evaluate Model
